# %% [markdown]
# # DATA ANALYSIS PROJECT

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## IMPORT & INSPECT DATA

# %%
startups = pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\Xslv Files project\startup-expansion.xlsx - Sheet1.csv")

# %%
startups
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#     Marketing Spend  Revenue
# 0            $2,601  $48,610
# 1            $2,727  $45,689
# 2            $2,768  $49,554
# ...

# %%
startups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int32
#  6   Revenue          150 non-null    int32
# dtypes: int32(2), int64(1), object(4)
# memory usage: 7.2+ KB

# %%
startups['Marketing Spend'] = startups['Marketing Spend'].replace('[\$,]','',regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16816\884595085.py:1: SyntaxWarning: invalid escape sequence '\$'
#   startups['Marketing Spend'] = startups['Marketing Spend'].replace('[\$,]','',regex=True).astype(int)

# %%
startups['Revenue'] = startups['Revenue'].replace('[\$,]','',regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16816\936664923.py:1: SyntaxWarning: invalid escape sequence '\$'
#   startups['Revenue'] = startups['Revenue'].replace('[\$,]','',regex=True).astype(int)

# %%
startups[['Marketing Spend','Revenue']].describe()
# Out:
#        Marketing Spend       Revenue
# count       150.000000    150.000000
# mean       2893.146667  39301.433333
# std         367.862817  15465.753977
# min        1811.000000  15562.000000
# 25%        2662.250000  21113.500000
# 50%        2898.000000  42993.000000
# 75%        3111.500000  51145.500000
# max        3984.000000  68828.000000

# %% [markdown]
# ## PREPROCESSING DATA

# %%
startups.isna().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
startups['City'].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
startups['City'].nunique()
# Out:
# 149

# %%
startups['State'].unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
startups['State'].nunique()
# Out:
# 35

# %%
startups['State'].value_counts()
# Out:
# State
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: count, dtype: int64

# %%
startups['State'].value_counts().nlargest(10)
# Out:
# State
# California     40
# Texas          17
# Florida        12
# Washington      7
# Colorado        5
# Illinois        5
# Georgia         4
# Alabama         4
# Connecticut     4
# New Jersey      4
# Name: count, dtype: int64

# %%
startups
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
startups['Sales Region'].value_counts()
# Out:
# Sales Region
# Region 2    86
# Region 1    64
# Name: count, dtype: int64

# %%
startups.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## EXPLORING AND ANALYSING DATA

# %%
startups.sample(10)
# Out:
#      Store ID         City          State Sales Region New Expansion  \
# 62         63     Richmond     California     Region 2           Old
# 137       138      Norwalk     California     Region 2           Old
# 15         16     Temecula     California     Region 2           Old
# 88         89        Vista     California     Region 2           Old
# 54         55  West Covina     California     Region 2           Old
# 100       101     Surprise        Arizona     Region 2           Old
# 108       109  Sioux Falls   South Dakota     Region 1           Old
# 52         53   Manchester  New Hampshire     Region 1           Old
# 132       133   Des Moines           Iowa     Region 1           Old
# 134       135   Santa Rosa     California     Region 2           Old
#
#      Marketing Spend  Revenue
# 62              3924    19448
# 137             3112    19703
# 15              2795    16690
# 88              2718    20949
# 54              2939    21824
# ...

# %%
startups['Sales Region'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sales Region'>

# %%
startups['New Expansion'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='New Expansion'>

# %%
startups[startups['New Expansion'] == 'Old'].groupby(['State']).sum()['Revenue'].nlargest(10)
# Out:
# State
# California     1362468
# Texas           554964
# Florida         479023
# Washington      298013
# Alabama         221025
# New York        160046
# Connecticut     158511
# Georgia         157656
# Colorado        156495
# Michigan        147759
# Name: Revenue, dtype: int32

# %%
startups[startups['New Expansion'] == 'New'].groupby(['State']).sum()['Revenue'].nlargest(10)
# Out:
# State
# California    141883
# Illinois       91692
# Texas          85605
# Tennessee      55357
# Arizona        48954
# New Jersey     34603
# Name: Revenue, dtype: int32

# %%
startups['Profit']= startups['Revenue']-startups['Marketing Spend']

# %%
startups['Profit']
# Out:
# 0      46009
# 1      42962
# 2      46786
# 3      35525
# 4      57018
#        ...
# 145    32352
# 146    59473
# 147    40729
# 148    19463
# 149    37710
# Name: Profit, Length: 150, dtype: int32

# %%
startups['ROM']= (startups['Profit']/startups['Marketing Spend'])*100

# %%
startups['ROM']
# Out:
# 0      1768.896578
# 1      1575.430876
# 2      1690.245665
# 3      1287.604204
# 4      1987.382363
#           ...
# 145    1437.227899
# 146    1618.312925
# 147    1538.104230
# 148     650.066800
# 149    1551.213492
# Name: ROM, Length: 150, dtype: float64

# %%
startups['ROM']= round(startups['ROM'],2)

# %%
startups['ROM']
# Out:
# 0      1768.90
# 1      1575.43
# 2      1690.25
# 3      1287.60
# 4      1987.38
#         ...
# 145    1437.23
# 146    1618.31
# 147    1538.10
# 148     650.07
# 149    1551.21
# Name: ROM, Length: 150, dtype: float64

# %%
startups.to_csv('startupsModified.csv')
